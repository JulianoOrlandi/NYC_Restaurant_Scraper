# %%
import pandas as pd

# %%
df =pd.read_csv("business_data.csv")

# %%
df.columns
# Out:
# Index(['types', 'nationalPhoneNumber', 'internationalPhoneNumber',
#        'formattedAddress', 'rating', 'googleMapsUri', 'priceLevel',
#        'userRatingCount', 'primaryType', 'location_latitude',
#        'location_longitude', 'displayName_text', 'displayName_languageCode',
#        'primaryTypeDisplayName_text', 'primaryTypeDisplayName_languageCode',
#        'googleMapsLinks_directionsUri', 'googleMapsLinks_placeUri',
#        'googleMapsLinks_writeAReviewUri', 'googleMapsLinks_reviewsUri',
#        'googleMapsLinks_photosUri', 'priceRange_startPrice_currencyCode',
#        'priceRange_startPrice_units', 'priceRange_endPrice_currencyCode',
#        'priceRange_endPrice_units', 'postalAddress_regionCode',
#        'postalAddress_languageCode', 'postalAddress_postalCode',
#        'postalAddress_administrativeArea', 'postalAddress_locality',
#        'postalAddress_addressLines', 'websiteUri'],
#       dtype='object')

# %%
filtro = df['displayName_text'].str.contains('paris', case=False, na=False)
df_filtrado = df[filtro]
df_filtrado
# Out:
#                                                                                                                                                                                                                                    types  \
# 2122                                                                                                                                       ['bakery', 'food_store', 'store', 'restaurant', 'point_of_interest', 'food', 'establishment']
# 2505                                                                                                                                           ['french_restaurant', 'cafe', 'restaurant', 'food', 'point_of_interest', 'establishment']
# 3286                                  ['coffee_shop', 'breakfast_restaurant', 'dessert_shop', 'confectionery', 'bakery', 'french_restaurant', 'cafe', 'food_store', 'store', 'restaurant', 'point_of_interest', 'food', 'establishment']
# ...
